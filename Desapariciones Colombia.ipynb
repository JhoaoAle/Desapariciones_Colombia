# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
from sodapy import Socrata

# %% [markdown]
# This project was conceived in the context of the International Day of the Victims of Enforced Disappearances (August 30)

# %% [markdown]
# ### Fetching data

# %%
#First we create the client to connect with the API
client = Socrata("www.datos.gov.co", 
                #SAMPLE_TEXT,
                 username="jhoao.a.martinez@gmail.com",
                 #password="SAMPLE_TEXT")

# Performing a query once to get the full dataset
results = client.get("8hqm-7fdt", limit=171796)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df = results_df.set_index('id')

# %% [markdown]
# ### Verifying the results

# %%
results_df
# Out:
#        estado_de_la_desaparici_n clasificaci_n_de_la_desaparici  \
# id
# 1                   Desaparecido                Sin Información
# 2                   Desaparecido                Sin Información
# 3                   Desaparecido                Sin Información
# 4                Aparecio Muerto                Sin Información
# 5                  Aparecio Vivo                Sin Información
# ...                          ...                            ...
# 171792             Aparecio Vivo                Sin Información
# 171793              Desaparecido                Sin Información
# 171794              Desaparecido                Sin Información
# 171795              Desaparecido                Sin Información
# 171796              Desaparecido                Sin Información
#
#        fecha_de_la_desaparici_n edad_al_momento_de_la sexo_del_desaparecido  \
# id
# 1       2006-12-29T00:00:00.000                    21                Hombre
# ...

# %% [markdown]
# ### Exporting the current info as a csv

# %% [markdown]
# This is done in order to not saturate the API

# %%
results_df.to_csv("Desapariciones.csv")
